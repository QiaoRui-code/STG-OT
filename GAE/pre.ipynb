# %%
import scanpy as sc

# %%
adata=sc.read_h5ad('/home/lenovo/jora/GAE/RTime_aligned_rotated.h5ad')
# Out:
# /home/lenovo/anaconda3/envs/graphode/lib/python3.8/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 78123 × 16379
#     obs: 'CellID', 'spatial_leiden_e30_s8', 'Batch', 'cell_id', 'seurat_clusters', 'inj_uninj', 'D_V', 'Annotation', 'time'
#     var: 'Gene'
#     uns: 'Annotation_colors', 'Injury_10DPI_rep1_SS200000147BL_B5', 'Injury_15DPI_rep4_FP200000266TR_E4', 'Injury_20DPI_rep2_SS200000147BL_B4', 'Injury_2DPI_rep1_SS200000147BL_D5', 'Injury_30DPI_rep2_FP200000264BL_A6', 'Injury_5DPI_rep1_SS200000147BL_D2', 'Injury_60DPI_rep3_FP200000264BL_A6', 'Injury_control_FP200000239BL_E3', 'angle_dict', 'transformation_parameters'
#     obsm: 'X_pca', 'X_spatial', 'spatial', 'spatial_aligned'
#     layers: 'counts'

# %%
pip install squidpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.5/180.5 kB 490.1 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 kB 727.3 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 933.5 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.9/206.9 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 1.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import squidpy as sq
# 直接加载，无需下载文件，会自动联网获取整理好的数据
# 这虽然是一张切片，但里面包含了不同的病理区域（DCIS vs IDC）
adata = sq.datasets.visium_hne_adata() 
# 或者加载 Andersson 2021 的特定数据
# 查看 adata.obs 里的注释，提取不同阶段
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/lenovo/anaconda3/envs/graphode/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-15-a99fbf076e69>", line 1, in <module>
#     import squidpy as sq
#   File "/home/lenovo/anaconda3/envs/graphode/lib/python3.8/site-packages/squidpy/__init__.py", line 1, in <module>
#     from squidpy import gr, im, pl, read, datasets
#   File "/home/lenovo/anaconda3/envs/graphode/lib/python3.8/site-packages/squidpy/gr/__init__.py", line 7, in <module>
#     from squidpy.gr._ppatterns import co_occurrence, spatial_autocorr
#   File "/home/lenovo/anaconda3/envs/graphode/lib/python3.8/site-packages/squidpy/gr/_ppatterns.py", line 232, in <module>
#     def _occur_count(
# ...
